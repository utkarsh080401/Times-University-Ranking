# %% [markdown]
# # Times Higher Education World University Rankings
#
# ![Imageoft](https://upload.wikimedia.org/wikipedia/en/7/74/WUR_logo_large.jpg)
#
# <style>
# td {
#   font-size: 50px
# }
# </style>
#
# Times Higher Education World University Rankings is an annual publication of university rankings by Times Higher Education (THE) magazine.
#
# The publication now comprises the world's overall, subject, and reputation rankings, alongside three regional league tables, Asia, Latin America, and BRICS & Emerging Economies which are generated by different weightings.
#
# THE Rankings is often considered as one of the most widely observed university rankings together with Academic Ranking of World Universities and QS World University Rankings.
#
# It is praised for having a new, improved ranking methodology since 2010; however, undermining of non-science and non-English instructing institutions and relying on subjective reputation survey are among the criticism and concerns.
#
# ![Imageofty](https://www.timeshighereducation.com/student/sites/default/files/methodology_2edit.jpg)
#
# ### Teaching: the learning environment
# For any student and any subject, the most directly relevant factor is the teaching environment: what it is like to learn at the university.
#
# The rankings are based on a strong belief that the quality of teaching at a university is itself predicated on the quality of its research: knowledge production and knowledge transfer at the university.
#
# For this reason, the Teaching metric is measured by five performance indicators: a reputation survey, the ratio of staff to students, the ratio of doctorate students to undergraduate students, the number of doctorates awarded per academic staff, and institutional income.
#
# These give a good indication of the prestige, facilities and resources of the teaching environment, all of which would have a direct impact on you, the student.
#
# ### Research
# A university might excel in teaching but not in research: a good teacher does not necessarily a good researcher make. But the quality and volume of research at an institution is nonetheless relevant to you if you are seeking the best academic experience.
#
# It is one thing to be taught about the ideas, theories and results at the forefront of academic advances, but quite another to be taught by the researchers responsible for such leaps.
#
# If you have the opportunity to learn from leading researchers, you will benefit both intellectually and practically. You will learn not just about the research they are doing, but also pick up essential intellectual skills that will serve you your whole life.
#
# At the best research institutions, you will also be able to take advantage of resources and facilities available only in such environments.
#
# The Research metric is measured by a reputation survey, which shows how university research is perceived by academic peers; research income, which indicates the importance and quality of research; and research productivity, which indicates how much high-quality research is published by academics at the institution.
#
# ### Citations: research influence
# The ultimate test of the quality of research is its impact, for all research aims to be influential and important.
#
# In the rankings, the research influence of a university is measured by the number of times that work by an academic at that university is cited by another scholar.
#
# The effect of research influence on your university experience is similar to the effect of research quality. The greater the number of citations of a university’s work, the more likely that you will engage with scholars who are leading and expanding the discussions in the field.
#
# Put more romantically, research impact is a reflection of how much an institution contributes to the worldwide project for collective and collaborative understanding of the world. This contribution is a both a measure of quality at a university, and a source of pride for both academics and students.
#
# ### Industry Income
# Mostly relevant for science, engineering, business and technology subjects, this factor is increasingly becoming a priority for universities and students. It indicates the commercial impact of an institution’s research, which is itself a reflection of the industrial value of the research.
#
# The industry income indicator is of fundamental importance if you prioritise the real-world application of the science and technology research.
#
# ### International Outlook
# Universities are no longer compared just with rivals in their own city, or even their own country; world-leading universities are competing globally and attracting students and researchers from across the world.
#
# International outlook is therefore a mark of a top institution, relevant both to international and domestic students.
#
# It is measured by three indicators: international to domestic student ratio, international to domestic staff ratio, and the proportion of research that involves international collaboration.
#
# The benefits of an international environment on campus range from cultivating open-minded discussions with diverse opinions to improving cross-cultural relations.
#
# But at a more basic level, an isolated institution without international connections simply cannot count itself among the world’s best universities in an increasingly global and mobile world.
#
# ### The Subject Rankings
# In addition to the THE World University Rankings, 11 individual subject rankings allow you to delve deeper across different disciplines: Arts and Humanities; Clinical, Pre-clinical and Health; Engineering and Technology; Life Sciences; Physical Sciences; Social Sciences; Law; Psychology; Education; Computer Science and Business and Economics.
#
# The 13 performances indicators are the same, but the weighting of each indicator is adjusted for the particular features and priorities of the discipline.

# %% [markdown]
# ### How to run the code
#
# This is an executable [*Jupyter notebook*](https://jupyter.org) hosted on [Jovian.ml](https://www.jovian.ml), a platform for sharing data science projects. You can run and experiment with the code in a couple of ways: *using free online resources* (recommended) or *on your own computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks. You can also select "Run on Colab" or "Run on Kaggle".
#
#
# #### Option 2: Running on your computer locally
#
# 1. Install Conda by [following these instructions](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). Add Conda binaries to your system `PATH`, so you can use the `conda` command on your terminal.
#
# 2. Create a Conda environment and install the required libraries by running these commands on the terminal:
#
# ```
# conda create -n zerotopandas -y python=3.8
# conda activate zerotopandas
# pip install jovian jupyter numpy pandas matplotlib seaborn opendatasets --upgrade
# ```
#
# 3. Press the "Clone" button above to copy the command for downloading the notebook, and run it on the terminal. This will create a new directory and download the notebook. The command will look something like this:
#
# ```
# jovian clone notebook-owner/notebook-id
# ```
#
#
#
# 4. Enter the newly created directory using `cd directory-name` and start the Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. Click on the notebook file (it has a `.ipynb` extension) to open it.

# %% [markdown]
# ## Downloading the Dataset
#
# We can use Kaggle and other Data Science forums for extracting the dataset for the project. I am using Kaggle for my project. We need our Kaggle Username and API Id for downloading the dataset to our notebook.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/mylesoneill/world-university-rankings'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./world-university-rankings" (use force=True to force download)

# %%
# Change this
data_dir = './world-university-rankings'

# %%
import os
os.listdir(data_dir)
# Out:
# ['school_and_country_table.csv',
#  'education_expenditure_supplementary_data.csv',
#  'cwurData.csv',
#  'educational_attainment_supplementary_data.csv',
#  'timesData.csv',
#  'shanghaiData.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "world-university-rankings" # change this (use lowercase letters and hyphens only)

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Updating notebook "utkarshmishra08/world-university-rankings" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/utkarshmishra08/world-university-rankings
# 'https://jovian.ai/utkarshmishra08/world-university-rankings'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# The dataset we downloaded is still not ready for exploratory analysis and visualization!
# Our dataset might contain some null values, some unnecessary data, irrelevant information etc.
# In order to get rid of these we'll use Pandas and Numpy.

# %%
import pandas as pd
import numpy as np

# %%
university_rankings_df= pd.read_csv(data_dir + '/timesData.csv')

# %%
university_rankings_df
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
#dropping female-male ratio and student staff ratio
university_rankings_df.drop('female_male_ratio',axis=1,inplace=True)

# %%
university_rankings_df.drop('student_staff_ratio',axis=1,inplace=True)

# %%
university_rankings_df.info() #getting information regrarding our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  international_students  2536 non-null   object
#  11  year                    2603 non-null   int64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 244.2+ KB

# %%
university_rankings_df.describe() #getting statistical information regarding our dataset
# Out:
#           teaching     research    citations         year
# count  2603.000000  2603.000000  2603.000000  2603.000000
# mean     37.801498    35.910257    60.921629  2014.075682
# std      17.604218    21.254805    23.073219     1.685733
# min       9.900000     2.900000     1.200000  2011.000000
# 25%      24.700000    19.600000    45.500000  2013.000000
# 50%      33.900000    30.500000    62.500000  2014.000000
# 75%      46.400000    47.250000    79.050000  2016.000000
# max      99.700000    99.400000   100.000000  2016.000000

# %% [markdown]
# .describe() and .info() are pandas methods that gives valuable insights regarding the dataset.

# %%
#checking whether there is a null value or not
university_rankings_df.isnull().sum()
# Out:
# world_rank                 0
# university_name            0
# country                    0
# teaching                   0
# international              0
# research                   0
# citations                  0
# income                     0
# total_score                0
# num_students              59
# international_students    67
# year                       0
# dtype: int64

# %% [markdown]
#  As there are some null values, we need to remove it.

# %%
#removing null values
university_rankings_df['num_students'].fillna(0,inplace=True)
university_rankings_df['international_students'].fillna(0,inplace=True)

# %%
university_rankings_df.isnull().sum() #now there is no null value.
# Out:
# world_rank                0
# university_name           0
# country                   0
# teaching                  0
# international             0
# research                  0
# citations                 0
# income                    0
# total_score               0
# num_students              0
# international_students    0
# year                      0
# dtype: int64

# %%
#type_check
university_rankings_df['international_students'].dtypes
# Out:
# dtype('O')

# %%
#taking care of '-'
tobereplace= university_rankings_df['income'][university_rankings_df['income']=='-']
for i in tobereplace:
    print(i)
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -

# %%
university_rankings_df.replace(to_replace = '-', value = 0,inplace=True)

# %%
#changing percentage to float
university_rankings_df['international_students'] = university_rankings_df['international_students'].str.rstrip('%').astype('float') / 100.0

# %%
#changing dtypes
university_rankings_df['international']= university_rankings_df['international'].astype('float')
university_rankings_df['income']= university_rankings_df['international'].astype('float')
university_rankings_df['total_score']= university_rankings_df['international'].astype('float')
university_rankings_df['num_students']= university_rankings_df['international'].astype('float')

# %%
#checking dtypes
university_rankings_df.dtypes
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international             float64
# research                  float64
# citations                 float64
# income                    float64
# total_score               float64
# num_students              float64
# international_students    float64
# year                        int64
# dtype: object

# %%
#checking tail
university_rankings_df.tail()
# Out:
#      world_rank               university_name      country  teaching  \
# 2598    601-800           Yeungnam University  South Korea      18.6
# 2599    601-800   Yıldız Technical University       Turkey      14.5
# 2600    601-800      Yokohama City University        Japan      24.0
# 2601    601-800  Yokohama National University        Japan      20.1
# 2602    601-800            Yuan Ze University       Taiwan      16.2
#
#       international  research  citations  income  total_score  num_students  \
# 2598           24.3      10.9       26.5    24.3         24.3          24.3
# 2599           14.9       7.6       19.3    14.9         14.9          14.9
# 2600           16.1      10.2       36.4    16.1         16.1          16.1
# 2601           23.3      16.0       13.5    23.3         23.3          23.3
# 2602           17.7      18.3       28.6    17.7         17.7          17.7
#
#       international_students  year
# 2598                    0.03  2016
# ...

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "utkarshmishra08/world-university-rankings" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/utkarshmishra08/world-university-rankings
# 'https://jovian.ai/utkarshmishra08/world-university-rankings'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# As we've complete data preparation and cleaning, now we'll derive valuable insights from our data and plot it using Matplotlib and Seaborn.

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %% [markdown]
# ### Installing plotly-express

# %%
# !pip install plotly-express

# %% [markdown]
# Importing Matplotlib.pylot and Seaborn

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Top 10 Universities

# %%
university_rankings_df.head(10)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
# 5          6                University of Cambridge            United Kingdom
# 6          6                   University of Oxford            United Kingdom
# 7          8     University of California, Berkeley  United States of America
# 8          9                Imperial College London            United Kingdom
# 9         10                        Yale University  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# ...

# %% [markdown]
# ## List of Countries included in the dataset.

# %%
university_rankings_df.country.unique()
# Out:
# array(['United States of America', 'United Kingdom', 'Switzerland',
#        'Canada', 'Hong Kong', 'Japan', 'South Korea', 'Singapore',
#        'Australia', 'China', 'France', 'Sweden', 'Germany',
#        'Republic of Ireland', 'Finland', 'Taiwan', 'South Africa',
#        'Turkey', 'Netherlands', 'Belgium', 'Denmark', 'Norway', 'Spain',
#        'New Zealand', 'Egypt', 'Austria', 'Israel', 'Brazil', 'Italy',
#        'Russian Federation', 'Greece', 'Iceland', 'Czech Republic',
#        'India', 'Poland', 'Iran', 'Portugal', 'Thailand', 'Chile',
#        'Estonia', 'Saudi Arabia', 'Mexico', 'Colombia', 'Macau',
#        'Morocco', 'Luxembourg', 'Unisted States of America', 'Cyprus',
#        'Unted Kingdom', 'Uganda', 'Malaysia', 'Lebanon', 'Romania',
#        'Slovenia', 'Pakistan', 'Hungary', 'United Arab Emirates',
#        'Belarus', 'Serbia', 'Slovakia', 'Bangladesh', 'Ghana', 'Nigeria',
#        'Indonesia', 'Jordan', 'Latvia', 'Kenya', 'Argentina', 'Qatar',
# ...

# %% [markdown]
# ## Countries containing top-10 ranked universities.

# %%
cntrytp= university_rankings_df.head(10).country
#print(len(cntrytp[cntrytp =='United Kingdom']))


langs=[]
for i in cntrytp.unique():
    langs.append(i)
#print(langs)
#print(len(langs))


tpten=[]
for j in range(0,len(langs)):
    tpten.append(len(cntrytp[cntrytp== langs[j]]))
#print(tpten)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')

myexplode = [0.2, 0]
ax.pie(tpten, labels = langs,explode=myexplode,autopct='%1.2f%%',shadow=True)
plt.show()

# %% [markdown]
# ## Top 10 Universities in India(acc. to total score)

# %%
india_df= university_rankings_df[university_rankings_df['country']=='India']

india_df.drop('country',axis=1,inplace=True)
india_df.sort_values('total_score',ascending=False).style.background_gradient(cmap='Blues',subset=["total_score"])\
                        .background_gradient(cmap='Greens',subset=["teaching"])\
                        .background_gradient(cmap='Purples',subset=["international"])\
                        .background_gradient(cmap='YlOrBr',subset=["research"])\
                        .background_gradient(cmap='Greens_r',subset=["citations"])\
                        .background_gradient(cmap='Greens_r',subset=["income"])\
                        .background_gradient(cmap='Greens_r',subset=["num_students"])\
                        .background_gradient(cmap='Greens_r',subset=["international_students"])\
                        .background_gradient(cmap='Greens_r',subset=["year"])
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <style  type="text/css" >
# #T_dbcb8_row0_col2{
#             background-color:  #edf8e9;
#             color:  #000000;
#         }#T_dbcb8_row0_col3{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_dbcb8_row0_col4{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_dbcb8_row0_col5{
#             background-color:  #1e8741;
#             color:  #000000;
# ...

# %% [markdown]
# ## Universities with more than 25% international students outside United Kingdom.

# %%
xii= university_rankings_df['international_students']>0.25

# %%
xjj= university_rankings_df['country']!= 'United Kingdom'

# %%
xiixjj = [xii[i] and xjj[i] for i in range(len(xii))]

# %%
university_rankings_df[xiixjj].sort_values('international_students',ascending=False).style.background_gradient(cmap='Blues',subset=["total_score"])\
                        .background_gradient(cmap='Greens',subset=["teaching"])\
                        .background_gradient(cmap='Purples',subset=["international"])\
                        .background_gradient(cmap='YlOrBr',subset=["research"])\
                        .background_gradient(cmap='Greens_r',subset=["citations"])\
                        .background_gradient(cmap='Greens_r',subset=["income"])\
                        .background_gradient(cmap='Greens_r',subset=["num_students"])\
                        .background_gradient(cmap='Greens_r',subset=["international_students"])\
                        .background_gradient(cmap='Greens_r',subset=["year"])
# Out:
# <style  type="text/css" >
# #T_731bb_row0_col3,#T_731bb_row47_col7,#T_731bb_row47_col9,#T_731bb_row79_col6{
#             background-color:  #f3faf0;
#             color:  #000000;
#         }#T_731bb_row0_col4,#T_731bb_row14_col4,#T_731bb_row38_col4{
#             background-color:  #4a1486;
#             color:  #f1f1f1;
#         }#T_731bb_row0_col5,#T_731bb_row122_col5{
#             background-color:  #fffee2;
#             color:  #000000;
# ...

# %%
tobesplit= university_rankings_df[xiixjj].groupby(['country']).size().reset_index(name='counts')
tobesplit['counts']
# Out:
# 0     75
# 1     15
# 2      5
# 3      1
# 4      9
# 5     23
# 6      1
# 7      2
# 8     11
# 9      7
# 10     1
# 11     2
# 12    12
# 13     2
# 14    19
# 15     2
# 16    56
# Name: counts, dtype: int64

# %% [markdown]
# ## Universities country-wise in above list

# %%
tobesplit= university_rankings_df[xiixjj].groupby(['country']).size().reset_index(name='counts')
xvalue= tobesplit['country']
yvalue= tobesplit['counts']


fig, ax = plt.subplots(figsize=(20, 12))

# Define x and y axes
ax.bar(xvalue, 
        yvalue,
        color = 'darkblue')

# Set plot title and axes labels
ax.set(title =  "Countries with universities having above 25% int. students",
       xlabel = "Countries",
       ylabel = "No. of Universities")
plt.setp(ax.get_xticklabels(), rotation = 42)
for i in range(len(xvalue)):
    plt.text(i,yvalue[i],str(yvalue[i]),size=(20),color='black',ha='center',va='bottom')

plt.show()

# %%
hubb= university_rankings_df.iloc[:200].groupby(['country']).size().reset_index(name='counts')
hubb
# Out:
#                      country  counts
# 0                  Australia       7
# 1                    Austria       2
# 2                    Belgium       2
# 3                     Canada       9
# 4                      China       6
# 5                    Denmark       3
# 6                      Egypt       1
# 7                    Finland       1
# 8                     France       4
# 9                    Germany      14
# 10                 Hong Kong       4
# 11                     Japan       5
# 12               Netherlands      10
# 13               New Zealand       1
# 14                    Norway       1
# 15       Republic of Ireland       2
# 16                 Singapore       2
# 17              South Africa       1
# 18               South Korea       4
# 19                     Spain       2
# 20                    Sweden       6
# 21               Switzerland       6
# 22                    Taiwan       4
# 23                    Turkey       2
# ...

# %% [markdown]
# ## Countries with universities in top-200

# %%
colors = np.random.randint(0,100,len(hubb))
fig, ax = plt.subplots(figsize=(20, 15))
ax.scatter(hubb['country'],hubb['counts'],s = hubb['counts']*100,c=colors)
ax.set(title =  "Countries with universities in top-200",
       xlabel = "Countries",
       ylabel = "No. of Universities")
plt.setp(ax.get_xticklabels(), rotation = 42)
                  

plt.show()

# %% [markdown]
# ## No. of universities with citation score >90

# %%
nlle= university_rankings_df[university_rankings_df['citations']>90.0]
hul= nlle.groupby(['country']).size().reset_index(name='counts')
np.array(hul['country'])



y=np.array(hul['country'])
  
# getting values against each value of y
x=np.array(hul['counts'])
plt.barh(y, x,color= 'r')
  
# setting label of y-axis
plt.ylabel("countries")
  
# setting label of x-axis
plt.xlabel("No. of universities") 
plt.title("No. of universities with citation score >90")
plt.show()

# %%
# !pip install plotly-express

# %%
import plotly_express as px

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "utkarshmishra08/world-university-rankings" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/utkarshmishra08/world-university-rankings
# 'https://jovian.ai/utkarshmishra08/world-university-rankings'

# %% [markdown]
# ## Asking and Answering Questions
#
# Here, some importamt answers will be derived from our data set

# %% [markdown]
# #### Q1: How many universities have more than half of their students international?

# %%
james= university_rankings_df[university_rankings_df['international_students']>0.5]
james.sort_values('international_students',ascending=False).style.background_gradient(cmap='Blues',subset=["total_score"])\
                        .background_gradient(cmap='Greens',subset=["teaching"])\
                        .background_gradient(cmap='Purples',subset=["international"])\
                        .background_gradient(cmap='YlOrBr',subset=["research"])\
                        .background_gradient(cmap='Greens_r',subset=["citations"])\
                        .background_gradient(cmap='Greens_r',subset=["income"])\
                        .background_gradient(cmap='Greens_r',subset=["num_students"])\
                        .background_gradient(cmap='Greens_r',subset=["international_students"])\
                        .background_gradient(cmap='Greens_r',subset=["year"])
# Out:
# <style  type="text/css" >
# #T_94dfb_row0_col3,#T_94dfb_row0_col10,#T_94dfb_row0_col11,#T_94dfb_row2_col11,#T_94dfb_row3_col7,#T_94dfb_row3_col9,#T_94dfb_row8_col11,#T_94dfb_row9_col11,#T_94dfb_row15_col6,#T_94dfb_row15_col11{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_94dfb_row0_col4{
#             background-color:  #6a51a3;
#             color:  #f1f1f1;
#         }#T_94dfb_row0_col5{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_94dfb_row0_col6,#T_94dfb_row1_col7,#T_94dfb_row1_col9,#T_94dfb_row3_col11,#T_94dfb_row10_col3,#T_94dfb_row10_col10,#T_94dfb_row10_col11,#T_94dfb_row11_col10,#T_94dfb_row12_col10,#T_94dfb_row13_col10,#T_94dfb_row14_col10,#T_94dfb_row15_col10{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_94dfb_row0_col7,#T_94dfb_row0_col9{
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }#T_94dfb_row0_col8{
# ...

# %% [markdown]
# #### Q.2: How many universities in India have research score more than 20?

# %%
jamesn= university_rankings_df['research']>20.0
jamesp= university_rankings_df['country']=='India'
jamesf = [jamesn[i] and jamesp[i] for i in range(len(jamesn))]
university_rankings_df[jamesf].sort_values('research',ascending=False).style.background_gradient(cmap='Blues',subset=["total_score"])\
                        .background_gradient(cmap='Greens',subset=["teaching"])\
                        .background_gradient(cmap='Purples',subset=["international"])\
                        .background_gradient(cmap='YlOrBr',subset=["research"])\
                        .background_gradient(cmap='Greens_r',subset=["citations"])\
                        .background_gradient(cmap='Greens_r',subset=["income"])\
                        .background_gradient(cmap='Greens_r',subset=["num_students"])\
                        .background_gradient(cmap='Greens_r',subset=["international_students"])\
                        .background_gradient(cmap='Greens_r',subset=["year"])
# Out:
# <style  type="text/css" >
# #T_9b878_row0_col3{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_9b878_row0_col4{
#             background-color:  #705eaa;
#             color:  #f1f1f1;
#         }#T_9b878_row0_col5{
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }#T_9b878_row0_col6{
#             background-color:  #84cc83;
#             color:  #000000;
#         }#T_9b878_row0_col7,#T_9b878_row0_col9{
#             background-color:  #bce4b5;
#             color:  #000000;
#         }#T_9b878_row0_col8{
#             background-color:  #2b7bba;
#             color:  #000000;
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Q3: Compare the quality of teaching among top 50 universities

# %%
jon= university_rankings_df['teaching'].iloc[:50]
jon2= np.arange(1,51)
color= np.random.randint(0,50,size=50)

plt.scatter(jon2,jon,c=color,s=50)

plt.xlabel("Global Rank")
plt.ylabel("Teaching Score")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.2)
z = np.polyfit(jon2, jon, 1)
p = np.poly1d(z)
plt.plot(jon2,p(jon2),"r--")


plt.show()

# %% [markdown]
# #### Q4: Compare the quality of research among german universities

# %%
jab= university_rankings_df[university_rankings_df['country']=='Germany']
jam=jab['research']

jam2= np.arange(0,len(jam))


#color= np.random.randint(0,200,size=len(jam))

plt.plot(jam2,jam)

plt.xlabel("Global Rank")
plt.ylabel("Teaching Score")
plt.grid(color = 'lightblue', linestyle = '--', linewidth = 0.2)
# z = np.polyfit(jam2, jam, 1)
# p = np.poly1d(z)
# plt.plot(jam2,p(jam),"b--")


plt.show()

# %% [markdown]
# #### Q5: Compare the top 10 swiss universities with top 10 indian universities(on the basis of research)

# %%
indo= university_rankings_df[university_rankings_df['country']=='India']
numb= np.arange(0,10)

indof= indo.sort_values('research', ascending=False).iloc[:10]['research']

german= university_rankings_df[university_rankings_df['country']=='Germany']
germanf= german.sort_values('research', ascending=False).iloc[:10]['research']
plt.plot(numb, indof, color='r', label='indian')
plt.plot(numb, germanf, color='g', label='german')
plt.xlabel('Universities')
plt.ylabel('Research Score')
plt.grid()
plt.show()

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Inferences and Conclusion
#
# 1. USA has most number of universities in top-100 in the world.
#
# 2. UK has most number of universities where more than 50% students are international.
#
# 3. Quality of teaching drastically reduces when one goes down the global rank with notable exceptions.
#
# 4. Research in top indian universities are way poorer than that of german universities.
#
# 5. IITs are among the top universities in India.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "utkarshmishra08/world-university-rankings" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/utkarshmishra08/world-university-rankings
# 'https://jovian.ai/utkarshmishra08/world-university-rankings'

# %% [markdown]
# ## References and Future Work
#
# Links to resources I found useful while making this project:-
#
# ### References:
#
# Stack Overflow Developer Survey
#
# Pandas user guide
#
# Matplotlib user guide
#
# Seaborn user guide & tutorial
#
# opendatasets Python library
#
# Kaggle dataset
#
# geeksforgeeks

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "utkarshmishra08/world-university-rankings" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/utkarshmishra08/world-university-rankings
# 'https://jovian.ai/utkarshmishra08/world-university-rankings'
